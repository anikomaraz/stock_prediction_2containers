# %%
# %pip install yfinance
# Out:
# ...
#   Using cached yfinance-0.1.87-py2.py3-none-any.whl (29 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# ...
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import necessary packages
import yfinance as yf
import pandas as pd

# %%
# !pip install yfinance
# Out:
# ...
#   Using cached lxml-4.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...

# %%
# get stock names
stock_names = pd.read_csv('~/code/rahulvaity25/stock_prediction/stock_prediction/raw_data/list_of_stocks_2017.csv')
stock_names = stock_names[['Name', 'Ticker']]
stock_names_list = list(stock_names['Ticker'])

stock_names_current = pd.read_csv('~/code/rahulvaity25/stock_prediction/stock_prediction/raw_data/nasdaq_current_list_12112012.csv')
stock_names_current = stock_names_current[['Symbol', 'Name']]
stock_names_current_list = list(stock_names_current['Symbol'])

stock_sample = '0005.HK'
# Out:
# /tmp/ipykernel_27300/772521087.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   stock_names = pd.read_csv('~/code/rahulvaity25/stock_prediction/stock_prediction/raw_data/list_of_stocks_2017.csv')

# %%
stock_names_current.head()
# Out:
#   Symbol                                               Name
# 0      A             Agilent Technologies Inc. Common Stock
# 1     AA                    Alcoa Corporation Common Stock
# 2    AAC  Ares Acquisition Corporation Class A Ordinary ...
# 3   AACG   ATA Creativity Global American Depositary Shares
# 4   AACI            Armada Acquisition Corp. I Common Stock

# %%
# get stock values

import yfinance as yf

data = yf.download(stock_sample, start="2015-01-01", end="2022-11-11")

data

data.to_csv('stock_price_sample.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  73.599998  74.099998  73.500000  74.000000  50.068130   8614012
# 2015-01-05  73.150002  73.349998  72.800003  72.900002  49.323879  21629040
# 2015-01-06  71.800003  71.849998  71.349998  71.750000  48.545784  35110417
# 2015-01-07  70.500000  71.099998  70.449997  71.000000  48.038334  35378291
# 2015-01-08  71.050003  71.400002  71.000000  71.199997  48.173649  21320949

# %%
import yfinance as yf

stock_list_full = list(stock_names['Ticker'])
stock_list_full
# Out:
# ['OEDV',
#  'AAPL',
#  'BAC',
#  'AMZN',
#  'T',
#  'GOOG',
#  'MO',
#  'DAL',
#  'AA',
#  'AXP',
#  'DD',
#  'BABA',
#  'ABT',
#  'UA',
#  'AMAT',
#  'AMGN',
#  'AAL',
#  'AIG',
#  'ALL',
#  'ADBE',
#  'GOOGL',
#  'ACN',
#  'ABBV',
#  'MT',
#  'LLY',
#  'AGN',
#  'APA',
#  'ADP',
#  'APC',
#  'AKAM',
#  'NLY',
#  'ABX',
#  'ATVI',
#  'ADSK',
#  'ADM',
#  'BMH.AX',
#  'WBA',
#  'ARNA',
#  'LUV',
#  'ACAD',
#  'PANW',
#  'AMD',
#  'AET',
#  'AEP',
#  'ALXN',
#  'CLMS',
#  'AVGO',
#  'EA',
#  'DB',
#  'RAI',
#  'AEM',
#  'APD',
#  'AMBA',
#  'NVS',
#  'APOL',
#  'ANF',
#  'LULU',
#  'RAD',
#  'BRK.AX',
#  'ARRY',
#  'AGNC',
#  'JBLU',
#  'A',
#  'ORLY',
#  'FOLD',
#  'AZO',
#  'ATML',
#  'AN',
#  'AZN',
#  'AES',
#  'GAS',
#  'BUD',
#  'ARR',
#  'BDX',
#  'AKS',
#  'AB',
#  'ACOR',
#  'CS',
#  'AFL',
#  'ADI',
#  'AEGR',
#  'ACIW',
#  'AMP',
#  'AVP',
#  'AMTD',
#  'AEO',
#  'AWK',
#  'NVO',
#  'ALTR',
#  'ALK',
#  'PAA',
#  'MTU.AX',
#  'ARCC',
#  'AAP',
#  'NAT',
#  'FNMA',
# ...

# %%
def get_stock_prices(stock): 

# get stock and ticker names (from current stocks only, list of ~ 8000)
    stock_names = pd.read_csv('~/code/rahulvaity25/stock_prediction/stock_prediction/raw_data/nasdaq_current_list_12112012.csv')
    stock_names = stock_names[['Symbol', 'Name']]
    
    # create a dictionary of stocks
    stock_dictionary = dict(zip(stock_names['Name'], # keys, verbose name of stock
                                stock_names['Symbol'])) # values, Ticker name
    
    # check if input query exists: 
    if stock in stock_dictionary.keys(): 
        # get stock ticker name from dictionary
        stock_ticker = stock_dictionary[stock]
        
        # find and download price data
        stock_price_historical = yf.download(stock_ticker, start="2021-01-01", end="2022-11-11")
        
        return stock_price_historical

# %%
yf.download('AAPL', start="2021-01-01", end="2022-11-11")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  127.874939
# 2021-01-05  128.889999  131.740005  128.429993  131.009995  129.455963
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  125.098267
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  129.367004
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  130.483627
# ...                ...         ...         ...         ...         ...
# 2022-11-04  142.089996  142.669998  134.380005  138.380005  138.380005
# 2022-11-07  137.110001  139.149994  135.669998  138.919998  138.919998
# 2022-11-08  140.410004  141.429993  137.490005  139.500000  139.500000
# 2022-11-09  138.500000  138.550003  134.589996  134.869995  134.869995
# 2022-11-10  141.240005  146.869995  139.500000  146.869995  146.869995
#
#                Volume
# Date
# ...

# %%
print(get_stock_prices(stock = 'Agilent Technologies Inc. Common Stock'))
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  118.940002  120.089996  117.110001  118.639999  117.405212
# 2021-01-05  118.480003  120.320000  118.070000  119.610001  118.365128
# 2021-01-06  118.690002  123.879997  118.209999  122.889999  121.610992
# 2021-01-07  124.330002  127.480003  124.110001  126.160004  124.846954
# 2021-01-08  126.489998  127.639999  125.849998  127.059998  125.737579
# ...                ...         ...         ...         ...         ...
# 2022-11-04  135.649994  137.009995  133.110001  136.080002  136.080002
# 2022-11-07  136.850006  138.080002  135.559998  138.029999  138.029999
# 2022-11-08  138.500000  140.690002  136.600006  138.750000  138.750000
# 2022-11-09  138.309998  139.419998  136.660004  137.000000  137.000000
# 2022-11-10  142.869995  146.720001  142.529999  146.300003  146.300003
#
#              Volume
# Date
# ...

# %%
stock_names = pd.read_csv('~/code/rahulvaity25/stock_prediction/stock_prediction/raw_data/nasdaq_current_list_12112012.csv')
stock_names
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $148.31
# 1        AA                    Alcoa Corporation Common Stock     $47.66
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...    $9.995
# 3      AACG   ATA Creativity Global American Depositary Shares     $1.79
# 4      AACI            Armada Acquisition Corp. I Common Stock     $9.98
# ...     ...                                                ...       ...
# 8311  ZWRKW                   Z-Work Acquisition Corp. Warrant    $0.001
# 8312    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $24.20
# 8313   ZYME                       Zymeworks Inc. Common Shares     $8.35
# 8314   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     $0.65
# 8315   ZYXI                            Zynex Inc. Common Stock    $13.00
#
#      Net Change  % Change   Market Cap        Country IPO Year      Volume  \
# ...
